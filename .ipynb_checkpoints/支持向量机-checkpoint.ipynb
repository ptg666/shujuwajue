# %%
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# 导入自己写的工具类
from my_tools import *
# 忽略warning
import warnings
warnings.filterwarnings("ignore")

# %%
jibing_res = pd.read_excel("./jibing_feature_res_final.xlsx")
jibing = pd.read_excel("./jibing_feature_final.xlsx")

# %% [markdown]
# ## 在SVM中连续型变量应尽可能归一化
# ### 11到60列是连续型的变量，要归一化

# %%
jibing.iloc[:,11:62].head()
# Out:
#     血红蛋白  红细胞压积  血小板计数  血小板压积  总蛋白g/L  白蛋白g/L  球蛋白g/L  白球比  AST天门冬氨酸氨基转移酶  \
# 0  154.0   45.9  274.0  0.228    72.9    45.4    27.5  1.7             17
# 1  124.0   36.3  172.0  0.130    62.2    37.6    24.6  1.5             22
# 2  127.0   38.4  166.0  0.158    74.3    44.5    29.8  1.5             16
# 3  157.0   47.0  219.0  0.200    74.2    48.4    25.8  1.9             20
# 4  159.0   48.2  205.0  0.190    73.0    48.9    24.1  2.0             20
#
#    碱性磷酸酶  ...  腺苷脱氨酶ADA   果糖胺   肌酸激酶  α-L-盐藻糖苷酶   乳酸    淀粉酶  同型半胱氨酸     铁  \
# 0    104  ...      10.0  1.97   62.0       18.0  1.4   80.0    23.0  14.2
# 1     74  ...      10.0  1.71   72.0       20.0  2.5  103.0    10.3   6.5
# 2     66  ...       9.0  1.67   32.0       17.0  1.3   52.0    10.7  25.3
# 3     86  ...       8.0  2.05  132.0       16.0  1.6   55.0    21.2  35.6
# 4     94  ...      10.0  1.72   81.0       22.0  1.2   81.0    14.8  20.1
#
#    总铁结合力  血型
# 0   51.6   0
# 1   57.1   2
# 2   64.1   0
# 3   71.3   0
# 4   61.4   3
#
# [5 rows x 49 columns]

# %%
jibing.index = range(jibing.shape[0])

# %% [markdown]
# ## 归一化

# %%
jibing = guiyihua(jibing)

# %%
jibing.head()
# Out:
#    左右  是否外伤  症状持续时间  明显夜间痛        年龄  高血压  高血脂  2型糖尿病  吸烟与否  饮酒与否  ...  \
# 0   1     0       3      0  0.078829    0    0      0     1   0.0  ...
# 1   1     0       4      0  0.119369    0    0      0     0   1.0  ...
# 2   1     0       4      0  0.031532    0    0      0     0   0.0  ...
# 3   1     0       4      1  0.096847    0    0      0     1   0.0  ...
# 4   1     0       4      1  0.081081    0    0      0     1   0.0  ...
#
#    腺苷脱氨酶ADA       果糖胺      肌酸激酶  α-L-盐藻糖苷酶        乳酸       淀粉酶    同型半胱氨酸  \
# 0  0.264471  0.005089  0.005220   0.120301  0.100775  0.276851  0.182004
# 1  0.264471  0.003586  0.006089   0.135338  0.186047  0.375267  0.052147
# 2  0.232491  0.003354  0.002614   0.112782  0.093023  0.157039  0.056237
# 3  0.200512  0.005552  0.011300   0.105263  0.116279  0.169876  0.163599
# 4  0.264471  0.003644  0.006870   0.150376  0.085271  0.281130  0.098160
#
#           铁     总铁结合力  血型
# 0  0.274194  0.434701   0
# 1  0.096774  0.537313   2
# 2  0.529954  0.667910   0
# 3  0.767281  0.802239   0
# 4  0.410138  0.617537   3
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 标准化

# %%
jibing = biaozhunhua(jibing)

# %%
jibing.head()
# Out:
#    左右  是否外伤  症状持续时间  明显夜间痛        年龄  高血压  高血脂  2型糖尿病  吸烟与否      饮酒与否  ...  \
# 0   1     0       3      0 -0.634697    0    0      0     1 -0.450418  ...
# 1   1     0       4      0  0.699734    0    0      0     0  2.220159  ...
# 2   1     0       4      0 -2.191532    0    0      0     0 -0.450418  ...
# 3   1     0       4      1 -0.041616    0    0      0     1 -0.450418  ...
# 4   1     0       4      1 -0.560562    0    0      0     1 -0.450418  ...
#
#    腺苷脱氨酶ADA       果糖胺      肌酸激酶  α-L-盐藻糖苷酶        乳酸       淀粉酶    同型半胱氨酸  \
# 0 -0.396096 -0.010001 -0.138369  -0.540229 -0.388337  0.565581  1.799019
# 1 -0.396096 -0.070029 -0.111576  -0.306733  1.067354  1.545136 -0.352195
# 2 -0.686176 -0.079264 -0.218748  -0.656976 -0.520673 -0.626921 -0.284440
# 3 -0.976257  0.008469  0.049182  -0.773724 -0.123666 -0.499153  1.494123
# 4 -0.396096 -0.067720 -0.087462  -0.073237 -0.653008  0.608170  0.410046
#
#           铁     总铁结合力  血型
# 0 -0.579652 -0.340355   0
# 1 -1.836937  0.265728   2
# 2  1.232798  1.037105   0
# 3  2.914620  1.830522   0
# 4  0.383722  0.739574   3
#
# [5 rows x 60 columns]

# %% [markdown]
# ## 使用SVC进行训练

# %%
from time import time
import datetime
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, recall_score

# %% [markdown]
# #### 划分训练集和测试集

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(jibing,jibing_res,test_size=0.3,random_state=90)

# %%
Xtrain.head()
# Out:
#       左右  是否外伤  症状持续时间  明显夜间痛        年龄  高血压  高血脂  2型糖尿病  吸烟与否      饮酒与否  ...  \
# 751    1     0       4      0 -0.338156    0    0      0     0 -0.450418  ...
# 631    0     0       4      0  0.329059    1    0      0     0 -0.450418  ...
# 1059   1     0       4      1  1.218679    0    0      0     0 -0.450418  ...
# 8      0     0       4      0  0.032519    1    0      0     1  2.220159  ...
# 1111   1     0       4      1  0.403194    0    0      0     0 -0.450418  ...
#
#       腺苷脱氨酶ADA       果糖胺      肌酸激酶  α-L-盐藻糖苷酶        乳酸       淀粉酶    同型半胱氨酸  \
# 751  -0.396096  0.001543  0.033106   0.510502 -0.785344 -0.371385  0.189843
# 631   0.474146 -0.143910 -0.092821  -0.306733 -0.917679  0.480402 -0.555459
# 1059  0.764226 -0.000766  0.067937  -0.540229 -0.388337 -0.158438  0.223721
# 8    -0.106015  0.017705  0.102768  -0.656976  0.141005 -0.371385  2.103916
# 1111  1.344387  0.008469 -0.122293   0.393754  0.935019  0.182277  0.376169
#
#              铁     总铁结合力  血型
# 751  -0.155114  1.334636   0
# 631  -1.543026 -0.384434   0
# 1059 -0.644966  0.464082   2
# 8    -0.073473  1.444833   0
# 1111 -1.934907  1.026085   0
#
# [5 rows x 60 columns]

# %%
Ytrain.head()
# Out:
#       结果
# 751    1
# 631    0
# 1059   0
# 8      0
# 1111   0

# %% [markdown]
# ### 存在样本不均衡的问题
# #### 但是不知道怎么处理

# %%
Ytrain.value_counts()
# Out:
# 结果
# 0     970
# 1     142
# dtype: int64

# %%
Ytest.value_counts()
# Out:
# 结果
# 0     419
# 1      58
# dtype: int64

# %% [markdown]
# ### 训练集的统计信息
# #### 没有过大或过小的数
# #### 数据预处理完毕

# %%
Xtrain.describe()
# Out:
#                 左右         是否外伤       症状持续时间        明显夜间痛           年龄  \
# count  1112.000000  1112.000000  1112.000000  1112.000000  1112.000000
# mean      0.661871     0.225719     3.396583     0.478417    -0.020216
# std       0.473286     0.418243     0.695949     0.499759     0.668738
# min       0.000000     0.000000     1.000000     0.000000    -3.229422
# 25%       0.000000     0.000000     3.000000     0.000000    -0.486427
# 50%       1.000000     0.000000     3.000000     0.000000     0.032519
# 75%       1.000000     0.000000     4.000000     1.000000     0.477329
# max       1.000000     1.000000     4.000000     1.000000     1.663489
#
#                高血压          高血脂        2型糖尿病         吸烟与否         饮酒与否  ...  \
# count  1112.000000  1112.000000  1112.000000  1112.000000  1112.000000  ...
# mean      0.341727     0.024281     0.127698     0.141187    -0.013327  ...
# std       0.476395     0.153988     0.333903     0.348371     0.988491  ...
# min       0.000000     0.000000     0.000000     0.000000    -0.450418  ...
# 25%       0.000000     0.000000     0.000000     0.000000    -0.450418  ...
# 50%       0.000000     0.000000     0.000000     0.000000    -0.450418  ...
# 75%       1.000000     0.000000     0.000000     0.000000    -0.450418  ...
# max       2.000000     1.000000     1.000000     1.000000     2.220159  ...
#
#           腺苷脱氨酶ADA          果糖胺         肌酸激酶    α-L-盐藻糖苷酶           乳酸  \
# count  1112.000000  1112.000000  1112.000000  1112.000000  1112.000000
# mean      0.022069     0.011090    -0.005474     0.017599     0.000530
# std       0.999889     1.194267     0.954102     1.075686     1.044085
# min      -2.136579    -0.197012    -0.299395    -2.408193    -2.108700
# 25%      -0.686176    -0.079264    -0.124973    -0.656976    -0.653008
# 50%      -0.106015    -0.034243    -0.071387    -0.073237    -0.256001
# 75%       0.474146     0.020013     0.006983     0.510502     0.405676
# max       5.985674    39.707970    30.547641    13.119263    14.962590
#
#                淀粉酶       同型半胱氨酸            铁        总铁结合力           血型
# count  1112.000000  1112.000000  1112.000000  1112.000000  1112.000000
# mean      0.016067    -0.002865    -0.005178    -0.002451     1.554856
# std       1.041020     1.035735     1.014001     0.997434     1.225536
# min      -2.189951    -1.199129    -2.522729    -2.907940     0.000000
# 25%      -0.669511    -0.538520    -0.693951    -0.670945     0.000000
# 50%      -0.158438    -0.174338    -0.106129     0.001255     2.000000
# 75%       0.522991     0.227955     0.547006     0.651416     3.000000
# max       7.763183    15.349975     4.563786     2.998608     3.000000
#
# [8 rows x 60 columns]

# %% [markdown]
# ### 训练

# %% [markdown]
# ### 要调的参数
# - 惩罚系数 C
# - 核函数
# - gamma

# %% [markdown]
# ### 使用不同核函数
# - 支持向量机可以通过核函数来将数据映射到更高维度，从而使模型更有效地拟合数据。
# - 有两种需要探索的核，poly，rbf

# %% [markdown]
# - ploy:多项式核
# - rbf:径向基函数

# %%
for kernel in ["poly","rbf"]:
    clf = SVC(kernel=kernel)
    clf.fit(Xtrain, Ytrain)
    y_pre = clf.predict(Xtest)
    metrics_ = res_metrics(Ytest,y_pre)
    print(kernel,metrics_)
# Out:
# poly {'precision': 0.8802521008403361, 'recall': 1.0, 'f1': 0.9363128491620112}
# rbf {'precision': 0.8784067085953878, 'recall': 1.0, 'f1': 0.9352678571428572}

# %% [markdown]
# ### rbf 是要优于 poly
# 选择 rbf 作为核函数，并进行调参

# %% [markdown]
# #### 调节 惩罚系数 和 gamma 值
# #### 网格搜索

# %%
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.1, 1, 10, 100]}
clf = SVC(kernel='rbf')
grid_search = GridSearchCV(clf, param_grid, cv=10)
grid_search.fit(Xtrain, Ytrain)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [0.1, 1, 10, 100]})

# %%
print(grid_search.best_params_)
# Out:
# {'C': 10, 'gamma': 0.1}

# %%
C = grid_search.best_params_["C"]
gamma = grid_search.best_params_["gamma"]
clf = SVC(kernel='rbf',C=C,gamma=gamma)

# %%
clf = clf.fit(Xtrain,Ytrain)
y_pre = clf.predict(Xtest)
metrics_ = res_metrics(Ytest,y_pre)
metrics_
# Out:
# {'precision': 0.8802521008403361, 'recall': 1.0, 'f1': 0.9363128491620112}
